# %% [markdown]
# # Drug Candidate Exploration
# Run `../scripts/07_depm_prism_drug_pilot.py` first.

# %%
import pandas as pd
candidates = pd.read_csv('../results/tables/drug_pilot_candidate_rankings.tsv', sep='\t')
candidates.head(20)
