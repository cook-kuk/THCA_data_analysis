# %% [markdown]
# # TCGA Bulk Exploration
# Run `../scripts/03_tcga_bulk_vulnerability.py` first, then inspect the generated score table and figures.

# %%
import pandas as pd
scores = pd.read_csv('../results/tables/tcga_thca_patient_vulnerability_scores.tsv', sep='\t')
scores.head()
