# %% [markdown]
# # Spatial Exploration
# Run `../scripts/05_spatial_vulnerability_mapping.py` first.

# %%
import pandas as pd
spots = pd.read_csv('../results/tables/spatial_spot_vulnerability_scores.tsv', sep='\t')
slides = pd.read_csv('../results/tables/spatial_slide_niche_summary.tsv', sep='\t')
spots.head(), slides.head()
