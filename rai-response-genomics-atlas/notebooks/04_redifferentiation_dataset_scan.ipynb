# %% [markdown]
# # Redifferentiation dataset scan (placeholder)
#
# **Tier 5 (treatment-induced redifferentiation).** Direction-of-effect: panel score should *rise* after successful MAPK / BRAF inhibition that restores iodide handling.
#
# ## Targets
#
# | Dataset | Trial / paper | Treatment | Expected effect |
# |---|---|---|---|
# | Ho 2013 NEJM | Selumetinib redifferentiation in RAIR-DTC | MEK inhibitor | panel z ↑ post-treatment in responders |
# | Rothenberg 2015 + MERAIODE 2023 | Dabrafenib + trametinib in BRAF-mut RAIR | MEKi + BRAFi | panel z ↑ in BRAF-mutant arm |
# | Vemurafenib (Brose 2016 Lancet Oncol) | BRAF-mut RAIR | BRAFi monotherapy | partial restoration |
# | GSE112202 | digoxin redifferentiation | digoxin | panel z ↑ in treated condition |
#
# ## Pipeline plan
#
# ```
# python3 scripts/02_download_geo_dataset.py GSE112202
# # Other trial datasets: scan their supplementary tables; many are paper-supplement-only.
# ```
#
# Per-trial direction-of-effect plot: pre-treatment panel z vs post-treatment panel z, paired per patient where available. Effect size = mean Δ panel z (post − pre).
#
# ## Manuscript wording template
#
# *"Across redifferentiation trial datasets (Tier 5), the 8-gene panel score increased after MAPK pathway inhibition in [N / M] paired samples (mean Δ panel z = TBD), consistent with restored iodide handling in patients reported as RAI-uptake responders."*
