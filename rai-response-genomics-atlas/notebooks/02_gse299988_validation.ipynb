# %% [markdown]
# # GSE299988 — RAI-avid vs non-avid small PTC cohort (placeholder)
#
# **Tier 2 (RAI avidity), supportive validation only.** Verify sample size and label structure on download — early entry expected ~10–30 samples.
#
# ## Plan
#
# ```
# python3 scripts/02_download_geo_dataset.py GSE299988
# python3 scripts/03_parse_geo_metadata.py GSE299988   # also check whether 03 parser needs new key-regex for this dataset's characteristics
# python3 scripts/04_score_gene_panel.py GSE299988    # may need different platform annotation extraction
# python3 scripts/05_validate_rai_labels.py GSE299988
# python3 scripts/06_make_figures.py GSE299988
# ```
#
# ## Notes
#
# - Treat as supportive cohort only. If panel directionality matches GSE151179 (refractory / non-avid lower than avid), include as supplement.
# - If platform is non-Clariom S, derive probe → gene mapping from that platform's `family.soft.gz` (same approach as `_extract_gpl23159_probe2gene.py`).
# - Adjacent normal samples (if present) provide an additional sanity check (tumor < normal panel z).
#
# ## Manuscript wording template
#
# *"In the independent GSE299988 cohort (n = TBD, Tier 2 RAI avidity), panel z [reproduced / failed to reproduce] the silencing direction observed in GSE151179, with [matching / divergent] effect size (Cohen d = TBD, AUC = TBD)."*
