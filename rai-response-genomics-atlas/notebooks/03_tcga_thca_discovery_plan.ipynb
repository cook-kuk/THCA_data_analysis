# %% [markdown]
# # TCGA-THCA discovery plan (placeholder)
#
# **Tier 4 (molecular proxy only). Discovery cohort. No direct RAI labels.**
#
# ## Status
#
# Paper 1 has already computed:
# - 8-gene panel z per sample (n ≈ 504) — `project/results/ncomm_push_2026_05_08/cbioportal_sweep/panel_expression_thpa_tcga_gdc.tsv`
# - Driver mutations (BRAF V600E, RAS, TERT promoter) — `project/manuscript_biorxiv_2026_05_20/supp_data_bundle/01_TCGA_d4p2_clin_mut.tsv`
# - HM450 β per sample for 8 genes — `/data/thca/repo_results/audit_2026_04_30/round5/r5_2_sample_methylation_8gene.tsv`
# - R17 two-axis zone per sample — `project/results/r17_tcga_panel_d4p2_reconciliation/r17_per_sample_merged.tsv`
#
# ## Plan in this workspace
#
# Do NOT re-derive from scratch. Re-use Paper 1 outputs and add an RAI-atlas-specific layer:
#
# 1. Symlink or copy the four files above into `data/external/tcga_paper1/` (small, MB-scale).
# 2. Score driver-stratified Cox PFI / DFI / OS / DSS within each panel-zone (extend R17 L6 with disease-free interval if available).
# 3. Build a panel-z × driver crosstab and emit `results/tables/tcga_panel_driver_crosstab.tsv`.
# 4. Document explicitly that **TCGA-THCA carries no direct RAI response field** and that all clinical readouts are Tier-4 proxies for the manuscript.
#
# ## Wording rule (TCGA-specific)
#
# Always tag TCGA-derived claims as 'Tier 4 proxy' in figure captions. Never write 'predicts RAI response' against TCGA-only data — only against Tier 1 / Tier 2 datasets.
