# %% [markdown]
# # Fig 3 — Trajectory and dedifferentiation (PTC → PDTC → ATC)
#
# ![Fig 3](Fig3_inline.png)
#
# ## What this figure shows
#
# Joint trajectory analysis (cPTC + FVPTC + PDTC + ATC, n = 670 across TCGA + GSE76039) places DM1 ATC-proximal and DM2 cPTC-proximal on a single dedifferentiation gradient. The recalculated RAI score correlates strongly with pseudotime (Spearman ρ = 0.74, p < 1e-15). A counter-intuitive finding becomes a strength after correct interpretation: **PDTC retains higher RAI score than ATC** (8.34–11.65 vs 2.89–7.62), which appears as 'perfect-separation, opposite-direction' (AUC 0.012 in raw histology-vs-RAI test) but actually confirms that DM2 captures preserved differentiation across the histology boundary. Our 8-gene panel recovers this ordering with **AUC 0.974** in correct-direction interpretation on GSE76039.
#
# ## Panels
#
# - **Panel a** — Pseudotime by histology (PTC / FVPTC / PDTC / ATC)
# - **Panel b** — RAI score by histology — PDTC retains higher RAI than ATC
# - **Panel c** — DM1/DM2 distribution along pseudotime (ATC-proximal evidence for DM1)
# - **Panel d** — AMP4 8-gene model ROC
#
# ## Headline number
#
# 8-gene panel correctly orders PTC → PDTC → ATC with AUC 0.974 (correct-direction).
#
# ## Source data
#
# - `/home/seungho/personal/THCA_data_analysis/project/results/v17/tables/trajectory_pseudotime.tsv`
# - `/home/seungho/personal/THCA_data_analysis/project/results/v17p3/tables/A6_pdtc_rai_validation.tsv`
# - `/home/seungho/personal/THCA_data_analysis/project/results/v17p35/tables/AMP4_roc_data.tsv`

# %%
import sys, warnings
warnings.filterwarnings('ignore')
sys.path.insert(0, '/home/seungho/personal/THCA_data_analysis/project/notebooks_or_scripts')
import pandas as pd, numpy as np
pd.set_option('display.max_columns', 12)
pd.set_option('display.width', 140)

from pathlib import Path
ROOT = Path('/home/seungho/personal/THCA_data_analysis/project/results')

# %% [markdown]
# ### Preview — `trajectory_pseudotime.tsv`

# %%
df = pd.read_csv('/home/seungho/personal/THCA_data_analysis/project/results/v17/tables/trajectory_pseudotime.tsv', sep='\t', low_memory=False); print('shape:', df.shape); df.head(8)

# %% [markdown]
# ### Preview — `A6_pdtc_rai_validation.tsv`

# %%
df = pd.read_csv('/home/seungho/personal/THCA_data_analysis/project/results/v17p3/tables/A6_pdtc_rai_validation.tsv', sep='\t', low_memory=False); print('shape:', df.shape); df.head(8)

# %% [markdown]
# ### Preview — `AMP4_roc_data.tsv`

# %%
df = pd.read_csv('/home/seungho/personal/THCA_data_analysis/project/results/v17p35/tables/AMP4_roc_data.tsv', sep='\t', low_memory=False); print('shape:', df.shape); df.head(8)

# %% [markdown]
# ## Final figure (Fig 3, all 4 panels composed)
#
# ![Fig 3 composed](../figures/Fig3.png)
#
# Figure built by: `notebooks_or_scripts/v17p35_SYNTH1_Fig3.py` (single self-contained Plotly script).
#
# Re-run via `python v17p35_SYNTH1_Fig3.py` from the project root to regenerate `figures/Fig3.{html,png,pdf}`.
