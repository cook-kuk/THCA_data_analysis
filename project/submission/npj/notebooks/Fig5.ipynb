# %% [markdown]
# # Fig 5 — Hot/cold immune landscape
#
# ![Fig 5](Fig5_inline.png)
#
# ## What this figure shows
#
# DM1 is a hot tumour state: GSEA shows enrichment for Inflammatory Response (NES = +1.93), IFN-γ Response (NES = +1.92), TNF-α via NF-κB (NES = +1.85), and Allograft Rejection (NES = +1.89), all with FDR < 1e-15. DM2 is reciprocally OxPhos-enriched (NES = −1.90, FDR = 0). scRNA of 66,000 cells from 7 patients shows immune-cell dominance ratio of 57 : 1 in DM1- vs DM2-skewed patients. Immune-evasion genes (PD-L1, IDO1, HLA-A/B/C, CTLA-4) are upregulated in DM1. The **integrated Hot/Cold composite** (z-normalised mean of cytolytic activity + IFN-γ + immune fraction) separates DM1 from DM2 with **Cohen's d = +1.683 (p = 4.0×10⁻¹⁸)** — a very large effect size that consolidates the four-layer evidence into one metric and supports DM1/DM2 as a checkpoint-immunotherapy stratification axis.
#
# ## Panels
#
# - **Panel a** — GSEA top inflammatory pathways (NES + FDR)
# - **Panel b** — scRNA immune cell breakdown by dominant DM
# - **Panel c** — Immune-evasion gene expression (cluster mean)
# - **Panel d** — Integrated Hot/Cold composite score (Cohen's d = +1.68, p = 4.0×10⁻¹⁸)
#
# ## Headline number
#
# Hot/Cold composite Cohen's d = +1.683 — very large effect size; immune-stratification candidate.
#
# ## Source data
#
# - `/home/seungho/personal/THCA_data_analysis/project/results/v17p3/tables/F2_gsea_hallmark_proper.tsv`
# - `/home/seungho/personal/THCA_data_analysis/project/results/v17p35/tables/FIX5_immune_cell_type_breakdown.tsv`
# - `/home/seungho/personal/THCA_data_analysis/project/results/v17p3/tables/A5_immune_evasion_genes.tsv`

# %%
import sys, warnings
warnings.filterwarnings('ignore')
sys.path.insert(0, '/home/seungho/personal/THCA_data_analysis/project/notebooks_or_scripts')
import pandas as pd, numpy as np
pd.set_option('display.max_columns', 12)
pd.set_option('display.width', 140)

from pathlib import Path
ROOT = Path('/home/seungho/personal/THCA_data_analysis/project/results')

# %% [markdown]
# ### Preview — `F2_gsea_hallmark_proper.tsv`

# %%
df = pd.read_csv('/home/seungho/personal/THCA_data_analysis/project/results/v17p3/tables/F2_gsea_hallmark_proper.tsv', sep='\t', low_memory=False); print('shape:', df.shape); df.head(8)

# %% [markdown]
# ### Preview — `FIX5_immune_cell_type_breakdown.tsv`

# %%
df = pd.read_csv('/home/seungho/personal/THCA_data_analysis/project/results/v17p35/tables/FIX5_immune_cell_type_breakdown.tsv', sep='\t', low_memory=False); print('shape:', df.shape); df.head(8)

# %% [markdown]
# ### Preview — `A5_immune_evasion_genes.tsv`

# %%
df = pd.read_csv('/home/seungho/personal/THCA_data_analysis/project/results/v17p3/tables/A5_immune_evasion_genes.tsv', sep='\t', low_memory=False); print('shape:', df.shape); df.head(8)

# %% [markdown]
# ## Final figure (Fig 5, all 4 panels composed)
#
# ![Fig 5 composed](../figures/Fig5.png)
#
# Figure built by: `notebooks_or_scripts/v17p35_SYNTH1_Fig5.py` (single self-contained Plotly script).
#
# Re-run via `python v17p35_SYNTH1_Fig5.py` from the project root to regenerate `figures/Fig5.{html,png,pdf}`.
