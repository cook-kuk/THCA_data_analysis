# %% [markdown]
# # Fig 7 — Drug actionability — mechanism-class enrichment
#
# ![Fig 7](Fig7_inline.png)
#
# ## What this figure shows
#
# **PRISM Repurposing 19Q4** primary-screen analysis on 11 PRISM-covered CCLE thyroid lines, with DM1/DM2 cluster assignment by within-thyroid-cohort z-score median split, recovers **perfect BRAF concordance** (4/4 BRAF V600E-mutant CCLE lines fall in DM1). At the per-compound level, the n = 5 vs n = 5 design limits FDR-grade single-drug discovery (0 compounds at FDR < 0.1 across 4,517 tested), but mechanism-class signals are coherent and biologically consistent: **MEK inhibitors are nominally DM1-selective** (nobiletin ΔLFC = −0.72, p = 0.016) and **HMGCR inhibitors are nominally DM1-selective** (procaine ΔLFC = −0.39, p = 0.032). We position this honestly as **hypothesis-generating for future targeted screens, not as a finalised clinical recommendation** — the manuscript is explicit about the n = 5 vs 5 limit.
#
# ## Panels
#
# - **Panel a** — DM1-selective drug volcano (Δ LFC vs −log10 p)
# - **Panel b** — MOA enrichment Δ count (DM1 − DM2)
# - **Panel c** — MEK + HMGCR class selectivity
# - **Panel d** — Cell-line DM1/DM2 axis with BRAF V600E lines (4/4 DM1)
#
# ## Headline number
#
# 4/4 BRAF concordance + MEK + HMGCR DM1-selective at mechanism-class level.
#
# ## Source data
#
# - `/home/seungho/personal/THCA_data_analysis/project/results/v17p35/tables/FIX1_top_drugs_dm1_selective_v2.tsv`
# - `/home/seungho/personal/THCA_data_analysis/project/results/v17p35/tables/FIX1_moa_enrichment_v2.tsv`
# - `/home/seungho/personal/THCA_data_analysis/project/results/v17p35/tables/FIX1_celline_dm_scores_v2.tsv`

# %%
import sys, warnings
warnings.filterwarnings('ignore')
sys.path.insert(0, '/home/seungho/personal/THCA_data_analysis/project/notebooks_or_scripts')
import pandas as pd, numpy as np
pd.set_option('display.max_columns', 12)
pd.set_option('display.width', 140)

from pathlib import Path
ROOT = Path('/home/seungho/personal/THCA_data_analysis/project/results')

# %% [markdown]
# ### Preview — `FIX1_top_drugs_dm1_selective_v2.tsv`

# %%
df = pd.read_csv('/home/seungho/personal/THCA_data_analysis/project/results/v17p35/tables/FIX1_top_drugs_dm1_selective_v2.tsv', sep='\t', low_memory=False); print('shape:', df.shape); df.head(8)

# %% [markdown]
# ### Preview — `FIX1_moa_enrichment_v2.tsv`

# %%
df = pd.read_csv('/home/seungho/personal/THCA_data_analysis/project/results/v17p35/tables/FIX1_moa_enrichment_v2.tsv', sep='\t', low_memory=False); print('shape:', df.shape); df.head(8)

# %% [markdown]
# ### Preview — `FIX1_celline_dm_scores_v2.tsv`

# %%
df = pd.read_csv('/home/seungho/personal/THCA_data_analysis/project/results/v17p35/tables/FIX1_celline_dm_scores_v2.tsv', sep='\t', low_memory=False); print('shape:', df.shape); df.head(8)

# %% [markdown]
# ## Final figure (Fig 7, all 4 panels composed)
#
# ![Fig 7 composed](../figures/Fig7.png)
#
# Figure built by: `notebooks_or_scripts/v17p35_SYNTH1_Fig7.py` (single self-contained Plotly script).
#
# Re-run via `python v17p35_SYNTH1_Fig7.py` from the project root to regenerate `figures/Fig7.{html,png,pdf}`.
