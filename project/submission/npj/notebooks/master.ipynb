# %% [markdown]
# # Master figure index + audit
#
# This notebook produces the browseable figure index (`figures/master_panel.html`) and the audit report (`figures/figure_audit_report.md`).
#
# ## Final figure inventory (8 main + 15 supplementary)
#
# ### Fig1
#
# ![](../figures/Fig1.png)
#
# ### Fig2
#
# ![](../figures/Fig2.png)
#
# ### Fig3
#
# ![](../figures/Fig3.png)
#
# ### Fig4
#
# ![](../figures/Fig4.png)
#
# ### Fig5
#
# ![](../figures/Fig5.png)
#
# ### Fig6
#
# ![](../figures/Fig6.png)
#
# ### Fig7
#
# ![](../figures/Fig7.png)
#
# ### Fig8
#
# ![](../figures/Fig8.png)
#
# ### SuppFig1
#
# ![](../figures/SuppFig1.png)
#
# ### SuppFig2
#
# ![](../figures/SuppFig2.png)
#
# ### SuppFig3
#
# ![](../figures/SuppFig3.png)
#
# ### SuppFig4
#
# ![](../figures/SuppFig4.png)
#
# ### SuppFig5
#
# ![](../figures/SuppFig5.png)
#
# ### SuppFig6
#
# ![](../figures/SuppFig6.png)
#
# ### SuppFig7
#
# ![](../figures/SuppFig7.png)
#
# ### SuppFig8
#
# ![](../figures/SuppFig8.png)
#
# ### SuppFig9
#
# ![](../figures/SuppFig9.png)
#
# ### SuppFig10
#
# ![](../figures/SuppFig10.png)
#
# ### SuppFig11
#
# ![](../figures/SuppFig11.png)
#
# ### SuppFig12
#
# ![](../figures/SuppFig12.png)
#
# ### SuppFig13
#
# ![](../figures/SuppFig13.png)
#
# ### SuppFig14
#
# ![](../figures/SuppFig14.png)
#
# ### SuppFig15
#
# ![](../figures/SuppFig15.png)
